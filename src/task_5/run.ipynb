# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/PointNet++"
# Out:
# config.py  models   PointNet++	    __pycache__
# data	   outputs  point_netpp.py  Stanford3dDataset_v1.2

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install open3d h5py tqdm scikit-learn seaborn matplotlib pandas blob
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
import os

# Path to the project in Google Drive
PROJECT_PATH = '/content/drive/MyDrive/PointNet++'

# Symlink to /content
#!ln -s "{PROJECT_PATH}" /content/PointNet++

# Add to Python path so imports work
import sys
sys.path.append('/content/PointNet++')

# Verify files are visible
# !ls /content/PointNet++
# Out:
# config.py  models   PointNet++	    __pycache__
# data	   outputs  point_netpp.py  Stanford3dDataset_v1.2

# %%
# %cd /content/PointNet++
# !python point_netpp.py
# Out:
# /content/drive/MyDrive/PointNet++
# Original labels shape: (44, 4096)
# Points per sample: 4096
# Converted labels shape: (44, 4096)
# Starting PointNet++ segmentation training on cuda
# Number of classes: 13
# Classes: ['ceiling', 'floor', 'wall', 'beam', 'column', 'window', 'door', 'table', 'chair', 'sofa', 'bookcase', 'board', 'clutter']
# Epoch 1/100 [Train]: 100% 4/4 [00:02<00:00,  1.59it/s, loss=2.3839, OA=21.88%]
#
# Epoch 1/100:
# Train Loss: 2.5464, Train OA: 14.25%, Train mIoU: 4.95%
# Val Loss: 2.5327, Val OA: 8.04%, Val mIoU: 0.68%
# Per-class IoU (Val):
#     ceiling        :   0.00%
#     floor          :   0.00%
#     wall           :   1.14%
#     beam           :   0.00%
#     column         :   0.00%
#     window         :   0.00%
#     door           :   0.00%
#     table          :   0.00%
#     chair          :   0.00%
#     sofa           :   0.00%
#     bookcase       :   0.00%
#     board          :   0.00%
#     clutter        :   7.75%
# ...

# %%
from google.colab import files
import os

# Download best model and plot
files.download("/content/drive/MyDrive/PointNet++/models/best_pointnet2_seg.pth")
files.download("/content/drive/MyDrive/PointNet++/outputs/training_history.png")
